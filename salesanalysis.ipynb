# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset (Replace with actual dataset path)
df = pd.read_csv('sales_data .csv')

# %%
df
# Out:
#            Date Region    Product  Quantity Sold  Unit Price     Revenue
# 0    2023-04-13  South  Product B             10   42.820358  428.203583
# 1    2024-03-11   East  Product C             14   12.838700  179.741802
# 2    2023-12-15   East  Product E             17   48.235125  819.997122
# 3    2023-09-28  South  Product E             18   23.715831  426.884967
# 4    2023-04-17  South  Product A             19   43.081038  818.539725
# ..          ...    ...        ...            ...         ...         ...
# 495  2023-04-24  North  Product C             10   12.048730  120.487297
# 496  2023-10-15   East  Product D             19    6.968103  132.393960
# 497  2024-03-06  North  Product B              3    9.986358   29.959075
# 498  2023-12-08  South  Product D             15   31.933921  479.008814
# 499  2023-05-31  South  Product A              1    9.275526    9.275526
#
# [500 rows x 6 columns]

# %%
df.head()
# Out:
#          Date Region    Product  Quantity Sold  Unit Price     Revenue
# 0  2023-04-13  South  Product B             10   42.820358  428.203583
# 1  2024-03-11   East  Product C             14   12.838700  179.741802
# 2  2023-12-15   East  Product E             17   48.235125  819.997122
# 3  2023-09-28  South  Product E             18   23.715831  426.884967
# 4  2023-04-17  South  Product A             19   43.081038  818.539725

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date             0
# Region           0
# Product          0
# Quantity Sold    0
# Unit Price       0
# Revenue          0
# dtype: int64

# %%
# Basic statistics of the dataset
df.describe()
# Out:
#                                 Date  Quantity Sold  Unit Price     Revenue
# count                            500     500.000000  500.000000  500.000000
# mean   2023-09-10 02:55:40.800000256      10.206000   27.082589  277.454987
# min              2023-01-02 00:00:00       1.000000    5.014963    5.406368
# 25%              2023-05-14 18:00:00       6.000000   16.157867  116.432114
# 50%              2023-09-09 00:00:00      10.000000   27.382684  235.056704
# 75%              2024-01-09 06:00:00      15.000000   37.336206  399.333863
# max              2024-05-14 00:00:00      19.000000   49.796622  893.186611
# std                              NaN       5.374508   12.491779  203.384943

# %%
# Convert date column to datetime format (if applicable)
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Sales trend over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Date', y='Revenue', hue='Region')
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
# Top performing products
top_products = df.groupby('Product')['Revenue'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_products.index, y=top_products.values, palette='viridis')
plt.title("Top 10 Products by Revenue")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-16-1b4546464b13>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_products.index, y=top_products.values, palette='viridis')

# %%
# Sales by region
plt.figure(figsize=(8, 5))
sns.boxplot(x='Region', y='Revenue', data=df, palette='Set2')
plt.title("Revenue Distribution by Region")
plt.show()
# Out:
# <ipython-input-17-3b3feaa940ab>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='Revenue', data=df, palette='Set2')

# %%
print("Sales Performance Analysis Completed. ")
# Out:
# Sales Performance Analysis Completed.
